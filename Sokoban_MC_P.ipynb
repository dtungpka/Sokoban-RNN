# %%
import gym
import gym_sokoban
import time
import datetime as dt
import matplotlib.pyplot as plt
import math
from collections import deque
import random
import numpy as np
import pickle
import sys
import tqdm
import os
from collections import namedtuple,defaultdict,deque

# %%
chapter = 0
level = 0


env_name = 'Sokoban-v1'
env = gym.make(env_name)
ACTION_LOOKUP = env.unwrapped.get_action_lookup()
env.unwrapped.set_level(chapter,level)
env.seed(0)
env.reset()
print("Created environment: {}".format(env_name))


#create Results/Chapter [chapter]/Level [level] folder
if not os.path.exists('Results/Chapter '+str(chapter)+'/Level '+str(level)):
    os.makedirs('Results/Chapter '+str(chapter)+'/Level '+str(level))
# Out:
# Created environment: Sokoban-v1

# %%
_ = env.reset()

# %%
env.render()
# Out:
# True

# %%
def map(x,  in_min,  in_max,  out_min,  out_max) :
  return (x - in_min) * (out_max - out_min) / (in_max - in_min) + out_min;

def greedy_policy(V,s,eps_comp=1e-8):
    #.9 prob of greedy action
    #.1 prob of random action

    if s not in V:
        V[s] = np.zeros(env.action_space.n)
    r_choice = 1 -map(eps_comp,0,1,0.1,.6)
    if np.random.random() < r_choice:
        return np.random.choice(np.arange(env.action_space.n))
    else:
        max_val = np.max(V[s])
         #find all actions that have the max value and choose one at random
        max_actions = np.argwhere(V[s] == max_val).flatten()
        return np.random.choice(max_actions)
def mod_P(P,state,action,next_state,reward):
    if state not in P:
        P[state] = {}
    if action not in P[state]:
        P[state][action] = [next_state,0,reward]
    else:
        P[state][action][0] = next_state
        P[state][action][2] = reward
    min_rw = 999999999999
    _tmp = [_r for _s,_a,_r in P[state].values()]
    _tmp = np.array(_tmp)
    #make sure all rewards are positive and sum to 1
    _tmp = _tmp - np.min(_tmp)
    _tmp = _tmp/np.sum(_tmp)
    
    for _i,_t in enumerate(P[state]):
        P[state][_t][1] = _tmp[_i]

# %%
EVERY_VISIT_MC = False
EPISODES = 100
V = {}
total_returns = {}
N = {}
P = {}
pbar = tqdm.tqdm(range(EPISODES),)
finished = 0
max_reward = 0
for episode in pbar:
    
    visited = []
    env.reset()
    state = env.unwrapped.serialize_state()
    done = False
    last_reward = 0
    for t in range(220):
        action_time = time.time()
        if done:
            break
        action = greedy_policy(V,state,eps_comp=episode/EPISODES)
        next_state, reward, done, info = env.step(action)
        if done and t < 159:
            finished += 1
        if reward > max_reward:
            max_reward = reward
       
        if EVERY_VISIT_MC or (not EVERY_VISIT_MC and state not in visited):
            if not EVERY_VISIT_MC:
                visited.append((state,action))
            if state not in total_returns:
                total_returns[state] = np.zeros(env.action_space.n)
            if state not in N:
                N[state] = np.zeros(env.action_space.n)
            for _state,_action in visited:
                total_returns[_state][_action] += reward
                N[_state][_action] += 1
                V[_state][_action] = (total_returns[_state][_action] / N[_state][_action])
                mod_P(P,state,action,next_state,(total_returns[_state][_action] / N[_state][_action]))
            
            
            #V[state][action] = (total_returns[state][action] / N[state][action])
        state = env.unwrapped.serialize_state()
        last_reward = reward
    pbar.set_description(f'Training MC, finished={finished};Max reward gained={round(max_reward,3)}')
    if episode % 1000 == 0:
        fname = 'Results/Chapter '+str(chapter)+'/Level '+str(level)+'/MC_'+('every' if EVERY_VISIT_MC else 'first')+'_'+str(EPISODES)+'_episodes_temp.bin'
        with open(fname, 'wb') as handle:
            pickle.dump(V, handle, protocol=pickle.HIGHEST_PROTOCOL)
        with open('Results/Chapter '+str(chapter)+'/Level '+str(level)+'/P_'+('every' if EVERY_VISIT_MC else 'first')+'_'+str(EPISODES)+'_episodes_temp.bin', 'wb') as handle:
            pickle.dump(P, handle, protocol=pickle.HIGHEST_PROTOCOL)


            
#save the value function
fname = 'Results/Chapter '+str(chapter)+'/Level '+str(level)+'/MC_'+('every' if EVERY_VISIT_MC else 'first')+'_'+str(EPISODES)+'_episodes.bin'
with open(fname, 'wb') as handle:
    pickle.dump(V, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open('Results/Chapter '+str(chapter)+'/Level '+str(level)+'/P_'+('every' if EVERY_VISIT_MC else 'first')+'_'+str(EPISODES)+'_episodes.bin', 'wb') as handle:
            pickle.dump(P, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]C:\Users\duong\AppData\Local\Temp\ipykernel_39220\2206912566.py:31: RuntimeWarning: invalid value encountered in divide
#   _tmp = _tmp/np.sum(_tmp)
# Training MC, finished=69;Max reward gained=35.886: 100%|██████████| 100/100 [00:34<00:00,  2.88it/s]

# %%
fname = 'Results/Chapter '+str(chapter)+'/Level '+str(level)+'/MC_'+('every' if EVERY_VISIT_MC else 'first')+'_'+str(EPISODES)+'_episodes.bin'
with open(fname, 'wb') as handle:
    pickle.dump(V, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
for s in V:
    argmax = np.argmax(V[s])
    max_val = np.max(V[s])
    s = s[26:40] +'\n'+ s[26+26:40+26]
    print("{} Action: {} Value: {}".format(s,ACTION_LOOKUP[argmax],max_val))
# Out:
# 37001000000833
# 30000700730553 Action: down Value: 11.434698421379244
# 37000000000833
# 30001700730553 Action: extinguish Value: 13.77710830503389
# 37000100000833
# 30000700730553 Action: left Value: 9.458390044858819
# 37000000000833
# 30000100730553 Action: down Value: 13.555995520004384
# 37000100000833
# 30000000730553 Action: extinguish Value: 12.427316269733907
# 37001000000833
# 30000000730553 Action: right Value: 9.330905605004048
# 37010000000833
# 30000000730553 Action: down Value: 10.360924743592541
# 37000000000833
# 30010000730553 Action: down Value: 14.625099661574152
# 37000000000833
# 30000000730553 Action: extinguish Value: 15.600341616742327
# 37000000000833
# 30000000730553 Action: extinguish Value: 16.688919597037355
# 37000000000833
# 30010000730553 Action: up Value: 16.74839334231231
# 37000000000833
# 30000000730553 Action: up Value: 18.169342083298574
# 37000000000833
# 30000000730553 Action: up Value: 15.280572583334617
# 37000000000833
# 30000000730553 Action: right Value: 9.865080823396372
# 37000000000833
# 30000000730553 Action: up Value: 13.051765525871277
# 37000000000833
# 30000000730553 Action: up Value: 6.185155288569495
# 37000000000833
# 30000000730553 Action: down Value: 5.2905549381156565
# 37000000000833
# 30000000730553 Action: up Value: 5.635213548883732
# 37000000000833
# 30100000730553 Action: up Value: 18.591733523669937
# 37000000000833
# 31000000730553 Action: right Value: 16.103317894235744
# 31000000000833
# 30000000730553 Action: right Value: 18.108794080336228
# 30000000000833
# 31000000730553 Action: right Value: 14.905001985052413
# 30000000000833
# 30000000730553 Action: right Value: 11.175291989253017
# 30000000000833
# 30000000730553 Action: up Value: 10.597225762247332
# 30000000000833
# 30000000730553 Action: right Value: 15.715265101147361
# 30000000000833
# 30000000730553 Action: up Value: 11.566225580870727
# 30000000000833
# 30000000730553 Action: up Value: 5.67394570699578
# 30000000000833
# 30000000730553 Action: up Value: 4.790249109813418
# 30000000000833
# 30000000730553 Action: up Value: 5.130288321814685
# 30000000000833
# 30000000730553 Action: left Value: 4.920808029197097
# 30000000000833
# 30000000730553 Action: up Value: 5.3171266562743424
# 30000000000833
# 30001000730553 Action: up Value: 6.312382273706899
# 30000000000833
# 30010000730553 Action: right Value: 6.603526131532884
# 30000000000833
# 30000000730553 Action: extinguish Value: 4.022346675070898
# 30000000000833
# 30000000730553 Action: up Value: 4.632527318932626
# 30000000000833
# 30000000730553 Action: up Value: 3.4766952595936633
# 30000000000833
# 30000000730553 Action: down Value: 4.4396000000000075
# 30000000000833
# 30000000730553 Action: up Value: 4.875642043366405
# 30000000000833
# 31000000730553 Action: up Value: 6.019860629067251
# 31000000000833
# 30000000730553 Action: right Value: 7.486052121212067
# 30100000000833
# 30000000730553 Action: left Value: 7.177625463535253
# 30000000000833
# 30100000730553 Action: right Value: 5.960934527911772
# 30000000000833
# 30000000730553 Action: right Value: 4.800829980842894
# 30001000000833
# 30000000730553 Action: right Value: 6.614456991359032
# 30000100000833
# 30000000730553 Action: up Value: 8.327166640012834
# 30010000000833
# 30000000730553 Action: down Value: 5.46223999999999
# 30000000000833
# 30000100730553 Action: left Value: 6.577827407407385
# 30000010000833
# 30000000730553 Action: extinguish Value: 8.302231250000045
# 30000001000833
# 30000000730553 Action: right Value: 6.081749999999984
# 30000000000833
# 30000001730553 Action: right Value: 9.114274308300377
# 30000000100833
# 30000000730553 Action: extinguish Value: 8.78103439490444
# 30000000000833
# 30000010730553 Action: right Value: 8.626301767676756
# 30000000000833
# 30000000730553 Action: right Value: 6.492309740970424
# 30000000000833
# 30000000730553 Action: down Value: 5.910568627450966
# 30000000000833
# 30000000730553 Action: right Value: 6.768593023255795
# 37010000000833
# 30000700730553 Action: extinguish Value: 12.195143661042069
# 37000000000833
# 30010700730553 Action: up Value: 11.419381986150036
# 37000000000833
# 30100700730553 Action: left Value: 9.59667335849538
# 37000000000833
# 30000700730553 Action: down Value: 9.871941184736153
# 37000000000833
# 30010700730553 Action: right Value: 9.137415850206827
# 37000000000833
# 30000700730553 Action: up Value: 9.388565975908447
# 37000000000833
# 30000700730553 Action: up Value: 6.9874479589968574
# 37000000000833
# 30100700730553 Action: up Value: 7.874156056747865
# 37000000000833
# 31000700730553 Action: extinguish Value: 6.906985653733278
# 37000000000833
# 30000700730553 Action: up Value: 3.4862627337201673
# 37000000000833
# 30001700730553 Action: up Value: 10.027177397786684
# 37000000000833
# 30000100730553 Action: left Value: 11.94964693276896
# 37000000000833
# 30000010730553 Action: left Value: 7.976007154568439
# 37000000000833
# 30000000730553 Action: extinguish Value: 5.969528297787589
# 37000010000833
# 30000000730553 Action: left Value: 10.109956587735219
# 37000000000833
# 30000000730553 Action: left Value: 3.701765436269976
# 37000000000833
# 30000000730553 Action: extinguish Value: 0.447887826492539
# 37000000000833
# 30000000730553 Action: left Value: 4.418574142839483
# 37000000000833
# 30000000730553 Action: down Value: 7.177323049811386
# 37000000000833
# 30000000730553 Action: left Value: 12.078954677764184
# 37000000000833
# 30001000730553 Action: left Value: 13.296127366670211
# 37000000000833
# 30010000730553 Action: down Value: 13.858775287431682
# 37000000000833
# 30100000730553 Action: extinguish Value: 12.507925824823918
# 37000000000833
# 30000000730553 Action: left Value: 5.691067630961679
# 37000000000833
# 30000000730553 Action: up Value: 5.690229379468863
# 37000000000833
# 30000000730553 Action: down Value: 4.3959960609693285
# 37000000000833
# 30000000730553 Action: extinguish Value: 4.655878982753587
# 37000000000833
# 30000000730553 Action: up Value: 8.270540630182412
# 37000000000833
# 30010000730553 Action: down Value: 9.175865979381427
# 37010000000833
# 30000000730553 Action: right Value: 5.9590292758089305
# 37001000000833
# 30000000730553 Action: right Value: 6.452206208425711
# 37000000000833
# 30000000730553 Action: left Value: 5.4659637214745365
# 37000000000833
# 30000000730553 Action: up Value: 4.089337803855822
# 37000000000833
# 30000000730553 Action: right Value: 3.6804970491803273
# 37000000000833
# 30000000730553 Action: down Value: 3.849999999999994
# 37000000000833
# 30000000730553 Action: right Value: 3.2616547314578006
# 37000000000833
# 31000000730553 Action: extinguish Value: 5.9313710937499975
# 37000000000833
# 30000700730553 Action: up Value: 11.372637655375668
# 37000000000833
# 30000700730553 Action: up Value: 9.362813419811511
# 37000000000833
# 30000700730553 Action: right Value: 5.497993572584664
# 37000000000833
# 30000700730553 Action: right Value: 8.096748594853814
# 37000000000833
# 30000700730553 Action: down Value: 8.887384221189338
# 37000000000833
# 30000700730553 Action: up Value: 6.880978496138233
# 37000000000833
# 30000700730553 Action: up Value: 3.292387153363473
# 37000000000833
# 30000700730553 Action: up Value: 1.3903209735146758
# 37000000000833
# 30000700730553 Action: up Value: 0.9272072632095558
# 37000000000833
# 30000700730553 Action: left Value: 0.22912058570199031
# 37000000000833
# 30000700730553 Action: left Value: 10.974287533942274
# 37000000000833
# 31000700730553 Action: up Value: 10.955843600384673
# 31000000000833
# 30000700730553 Action: extinguish Value: 13.939423075725417
# 30000000000833
# 31000700730553 Action: right Value: 12.733847431555413
# 30100000000833
# 30000700730553 Action: down Value: 13.372150343234095
# 30000000000833
# 30100700730553 Action: extinguish Value: 14.231007956012725
# 30000000000833
# 30010700730553 Action: down Value: 13.949887561647353
# 30000000000833
# 30001700730553 Action: left Value: 10.203989551383552
# 30000000000833
# 30000700730553 Action: extinguish Value: 15.399418416561577
# 30000000000833
# 30000700730553 Action: right Value: 16.280117071995534
# 30000000000833
# 30000700730553 Action: extinguish Value: 14.667042226663373
# 30000000000833
# 30100700730553 Action: up Value: 13.243512484305894
# 30000000000833
# 31000700730553 Action: right Value: 13.052188427793991
# 31000000000833
# 30000700730553 Action: right Value: 11.269051702436602
# 30000000000833
# 30000700730553 Action: up Value: 12.992318020673117
# 30100000000833
# 30000700730553 Action: right Value: 13.855917044752038
# 30000000000833
# 30000700730553 Action: up Value: 11.494478551630056
# 30000000000833
# 30000700730553 Action: left Value: 10.460407518876368
# 30010000000833
# 30000700730553 Action: down Value: 14.91261144158482
# 30000000000833
# 30010700730553 Action: extinguish Value: 15.983171504397413
# 30000000000833
# 30000700730553 Action: left Value: 16.75815753186746
# 30000000000833
# 30001700730553 Action: right Value: 17.748054157522155
# 30000000000833
# 30000700730553 Action: extinguish Value: 5.7398343919728205
# 30000000000833
# 30000700730553 Action: left Value: 4.500786197564241
# 30000000000833
# 30000700730553 Action: right Value: 4.269448439620068
# 30000000000833
# 30000700730553 Action: up Value: 4.254271938441374
# 30000000000833
# 30000700730553 Action: extinguish Value: 4.890768770152007
# 30000000000833
# 30000700730553 Action: right Value: 4.206035842293907
# 37000000000833
# 30001000730553 Action: left Value: 13.447335122854355
# 37000000000833
# 30000000730553 Action: left Value: 15.881778473370678
# 30100000000833
# 30000000730553 Action: right Value: 18.751502640322933
# 30000000000833
# 30000000730553 Action: up Value: 7.950952669902924
# 30000000000833
# 30000000730553 Action: up Value: 3.441118826405857
# 30000000000833
# 30000000730553 Action: up Value: 1.1357927241962784
# 30000000000833
# 30000000730553 Action: extinguish Value: -10.469707988980721
# 30000000000833
# 30000000730553 Action: right Value: -14.017265107212463
# 30000000000833
# 30000000730553 Action: right Value: -7.025135990621327
# 30000000000833
# 30000000730553 Action: up Value: -43.25747569955817
# 30000000000833
# 30000000730553 Action: down Value: -51.56447142857131
# 30000000000833
# 30000000730553 Action: left Value: -53.306213276836104
# 30000000000833
# 30000000730553 Action: left Value: -52.29559431137717
# 30000000000833
# 30000000730553 Action: extinguish Value: -52.73036342042752
# 30000000000833
# 30000000730553 Action: right Value: -45.61419047619047
# 30000000000833
# 30000000730553 Action: down Value: -42.27060119047618
# 30000000000833
# 30000000730553 Action: right Value: -78.36911267605633
# 30000000000833
# 30000000730553 Action: right Value: 0.0
# 30000000000833
# 30000000730553 Action: down Value: 0.0
# 30000000000833
# 30100000730553 Action: up Value: -81.94065624999999
# 30000000000833
# 30010000730553 Action: up Value: 0.0
# 30100000000833
# 30000000730553 Action: right Value: 0.0
# 31000000000833
# 30000000730553 Action: extinguish Value: -84.21762184873947
# 30000000000833
# 31000000730553 Action: left Value: 0.0
# 30000000000833
# 30000000730553 Action: down Value: -81.05154545454543
# 30000000000833
# 30001000730553 Action: up Value: 0.0
# 30000000000833
# 30000100730553 Action: right Value: 0.0
# 30000000000833
# 30000000730553 Action: right Value: 0.0
# 30000000000833
# 30000000730553 Action: right Value: 0.0
# 30000100000833
# 30000000730553 Action: right Value: 0.0
# 30001000000833
# 30000000730553 Action: right Value: 0.0
# 37000000000833
# 30000001730553 Action: up Value: 4.571670103092767
# 37000001000833
# 30000000730553 Action: right Value: 6.263059379358417
# 37000000100833
# 30000000730553 Action: right Value: 8.304773096250463
# 37000000000833
# 30000000130553 Action: up Value: 2.0116242437575247
# 37000000000833
# 30000001030553 Action: right Value: 2.0331161383830247
# 37000001000833
# 30000000030553 Action: left Value: 3.482146360702736
# 37000000100833
# 30000000030553 Action: left Value: 2.7463258724428106
# 37000000010833
# 30000000030553 Action: right Value: 2.866852065585769
# 37000000001833
# 30000000030553 Action: right Value: 3.730780757279294
# 37000000000833
# 30000000031553 Action: right Value: 7.540087403598939
# 37000000001033
# 30000000030553 Action: right Value: 5.490347015535559
# 37000000010033
# 30000000030553 Action: extinguish Value: 5.696856966326842
# 37000000000133
# 30000000030553 Action: down Value: 5.362670052480105
# 37000000000033
# 30000000030153 Action: right Value: 5.4941018284106855
# 37000000000033
# 30000000030553 Action: right Value: 10.766120367790496
# 37000000000033
# 30000000031553 Action: left Value: 4.210982595870209
# 37000000000033
# 30000000030553 Action: up Value: 7.955626158599375
# 37000000000033
# 30000000030553 Action: up Value: 7.699696969696966
# 37000000000033
# 30000000030553 Action: left Value: -2.3416117775354466
# 37000000000033
# 30000000030553 Action: left Value: 5.178455426356587
# 37000000000033
# 30000000030553 Action: extinguish Value: 3.1402657299938816
# 37000000000033
# 30000000030553 Action: up Value: 7.674066822977727
# 37000000000033
# 30000000030553 Action: left Value: 8.688839790575903
# 37000000000033
# 30000000030553 Action: up Value: 2.5646427104722687
# 37000000000033
# 30000000030553 Action: right Value: 12.159643233743388
# 37000000000033
# 30000000030553 Action: right Value: 12.715061519903461
# 37000000000033
# 30000000030553 Action: down Value: 10.529712418300646
# 37000000000033
# 30000000030553 Action: right Value: 14.297011278195459
# 37000000000833
# 30000010730553 Action: right Value: 11.781198248138576
# 37000000000833
# 30000000730553 Action: up Value: 8.268585877804876
# 37100000000833
# 30000000730553 Action: up Value: 10.048481986867605
# 37000000000833
# 30100000730553 Action: extinguish Value: 11.70334648983481
# 37000000000833
# 31000000730553 Action: up Value: 10.764128454996392
# 31000000000833
# 30000000730553 Action: up Value: 11.574437108708146
# 30000000000833
# 31000000730553 Action: up Value: 10.679504634527232
# 30100000000833
# 30000000730553 Action: right Value: 10.11137154110281
# 30010000000833
# 30000000730553 Action: down Value: 9.833351278195497
# 30000000000833
# 30010000730553 Action: down Value: 12.42480848029662
# 30000000000833
# 30100000730553 Action: left Value: 7.534534169177759
# 30000000000833
# 30001000730553 Action: left Value: 7.876180966533125
# 30001000000833
# 30000000730553 Action: up Value: 7.376690266389981
# 30000100000833
# 30000000730553 Action: left Value: 4.530660883757473
# 30000000000833
# 30000000730553 Action: left Value: 6.625966557413438
# 30000000000833
# 30100000730553 Action: right Value: 16.075459105473684
# 30000000000833
# 30010000730553 Action: down Value: 20.16805743646297
# 30000000000833
# 30000000730553 Action: extinguish Value: 7.939886445437651
# 30000000000833
# 30000000730553 Action: up Value: 18.687156912701692
# 30000000000833
# 30000000730553 Action: down Value: 5.732415042614448
# 30000000000833
# 30000000730553 Action: down Value: 5.646936315901542
# 30000000000833
# 30000000730553 Action: up Value: 5.473354602723021
# 30000000000833
# 31000000730553 Action: extinguish Value: 5.840288530268842
# 30000000000833
# 30100000730553 Action: down Value: 5.414392527092621
# 30000000000833
# 30010000730553 Action: right Value: 6.172257200145868
# 30000000000833
# 30000000730553 Action: right Value: 5.23425895737816
# 30000000000833
# 30000000730553 Action: down Value: 4.855991743156069
# 30000000000833
# 30000000730553 Action: left Value: 5.190714019272648
# 30000000000833
# 30000000730553 Action: right Value: 5.723690227848078
# 30000000000833
# 30000000730553 Action: up Value: 7.165018607635564
# 30000000000833
# 30000000730553 Action: up Value: 8.093635230577457
# 30000000000833
# 30000000730553 Action: left Value: 8.100156662269075
# 30000000000833
# 30000000730553 Action: up Value: 8.337466741826388
# 30000000000833
# 31000000730553 Action: right Value: 8.359355042966989
# 31000000000833
# 30000000730553 Action: right Value: 8.157258034894392
# 30100000000833
# 30000000730553 Action: extinguish Value: 8.309395555555573
# 30010000000833
# 30000000730553 Action: right Value: 8.369197592067984
# 30000000000833
# 30010000730553 Action: left Value: 8.624773959526511
# 30001000000833
# 30000000730553 Action: down Value: 8.390284837323492
# 30000000000833
# 30001000730553 Action: left Value: 8.421651791326195
# 30000000000833
# 30000000730553 Action: extinguish Value: 8.342301993067553
# 30000000000833
# 30100000730553 Action: right Value: 8.586502131546858
# 30000000000833
# 30000000730553 Action: up Value: 8.448349514563102
# 30000000000833
# 30000000730553 Action: up Value: 8.081793351302768
# 30000000000833
# 30000100730553 Action: right Value: 8.505525854513536
# 30000000000833
# 30000010730553 Action: left Value: 8.600121787709499
# 30000010000833
# 30000000730553 Action: left Value: 7.992789954337888
# 30000100000833
# 30000000730553 Action: down Value: 8.243923076923071
# 37000010000833
# 30000700730553 Action: left Value: 7.121072455177309
# 37000001000833
# 30000700730553 Action: right Value: 6.996665717726918
# 37000000100833
# 30000700730553 Action: extinguish Value: 9.576760032102724
# 37000000010833
# 30000700730553 Action: up Value: 8.737192405430886
# 37000000000833
# 30000700130553 Action: down Value: 9.7645809815636
# 37000000100833
# 30000700030553 Action: right Value: 10.38424805801039
# 37000000010833
# 30000700030553 Action: up Value: 12.175545943250693
# 37000000001833
# 30000700030553 Action: extinguish Value: 13.820347744646307
# 37000000000833
# 30000700031553 Action: up Value: 12.324136562336092
# 37000000000833
# 30000701030553 Action: up Value: 7.600602326968973
# 37000000000833
# 30000710030553 Action: right Value: 7.788055963413117
# 37000010000833
# 30000700030553 Action: right Value: 5.3291749635941645
# 37000001000833
# 30000700030553 Action: right Value: 7.9388313626304114
# 37000000001033
# 30000700030553 Action: right Value: 14.216879218620015
# 37000000000133
# 30000700030553 Action: down Value: 14.793373831775662
# 37000000000033
# 30000700030153 Action: down Value: 16.046704933255846
# 37000000000033
# 30000700030553 Action: down Value: 17.547583080513316
# 37000000000033
# 30000700031553 Action: extinguish Value: 14.657600787957103
# 37000000000033
# 30000700030553 Action: left Value: 16.137030955396074
# 37000000000033
# 30000700030553 Action: down Value: 14.94331528588092
# 37000000000033
# 30000700030553 Action: right Value: 14.003575912122306
# 37000000000033
# 30000700030553 Action: right Value: 7.096947743467932
# 37000000000033
# 30000700030553 Action: left Value: 7.3079396681749484
# 37000000000033
# 30000700030553 Action: right Value: 8.76326620370369
# 37000000000033
# 30000700030553 Action: extinguish Value: 8.670925650557619
# 37000000000033
# 30000700030553 Action: right Value: 8.113163017031626
# 37000000000033
# 30000700030553 Action: left Value: 4.30303703703704
# 37000000010833
# 30000000030553 Action: right Value: 0.0
# 37000000000833
# 30000000730553 Action: extinguish Value: 6.039466577166213
# 37000000000833
# 30000000730553 Action: left Value: 3.4725967966201345
# 37000000000833
# 30000000730553 Action: right Value: 5.435692929768756
# 37000000000833
# 30000000730553 Action: extinguish Value: 5.22821589440649
# 37000000000833
# 30000000730553 Action: left Value: 6.752914703694504
# 37000000000833
# 30000000730553 Action: up Value: 9.481883888388804
# 37000000000833
# 30000000730553 Action: up Value: 3.9454364540383144
# 37000000000833
# 30000000730553 Action: up Value: 2.327746536203528
# 37000000000833
# 30000000730553 Action: up Value: 1.232599391243269
# 37000000000833
# 30000000730553 Action: left Value: 3.434134877719041
# 37000000000833
# 30000000730553 Action: left Value: 5.409803259027956
# 37000000000833
# 30000000730553 Action: left Value: 7.82634105187394
# 37000000000833
# 30000000730553 Action: right Value: 8.789152334758276
# 37000000000833
# 30000000730553 Action: right Value: 5.768405681371905
# 37000000000833
# 30000000730553 Action: left Value: 10.334984905660342
# 37000000000833
# 30000000730553 Action: up Value: -1.3465230943610322
# 37000000000833
# 30000000730553 Action: extinguish Value: 9.736566311238672
# 37000000000833
# 30000000730553 Action: up Value: 9.189192215013843
# 37000000000833
# 30000000730553 Action: down Value: 9.138261018292482
# 37000000000833
# 30000000730553 Action: up Value: 12.619535699774685
# 37000000000833
# 30000000730553 Action: up Value: 8.18569134906232
# 37000000000833
# 30000000730553 Action: up Value: 7.362189695550311
# 37000000000833
# 30040000730553 Action: up Value: 9.903064498908023
# 37000000000833
# 30040000730553 Action: right Value: 7.300564495851145
# 37000000000833
# 30040000730553 Action: extinguish Value: 7.485319055287117
# 37000000000833
# 30040000730553 Action: up Value: 5.266278663239068
# 37000000000833
# 30040000730553 Action: extinguish Value: 8.31137849162011
# 37000000000833
# 31040000730553 Action: extinguish Value: 10.374481337480592
# 31000000000833
# 30040000730553 Action: extinguish Value: 8.571230145683392
# 30100000000833
# 30040000730553 Action: right Value: 10.647271125169446
# 30010000000833
# 30040000730553 Action: down Value: 11.307302295918381
# 30000000000833
# 30140000730553 Action: up Value: 7.933011009174316
# 30000000000833
# 30040000730553 Action: up Value: 8.60374074074073
# 30000000000833
# 30040000730553 Action: left Value: 7.559454665784252
# 30040000000833
# 30010000730553 Action: left Value: 1.8995284636488194
# 30040000000833
# 30100000730553 Action: down Value: 4.442590718143642
# 30040000000833
# 31000000730553 Action: right Value: 2.5257176470588045
# 30140000000833
# 30000000730553 Action: extinguish Value: 3.082468379446625
# 30040000000833
# 30000000730553 Action: extinguish Value: 4.654472226694602
# 30040000000833
# 30000000730553 Action: left Value: 4.93003472107951
# 30040000000833
# 30000000730553 Action: right Value: 1.3475371053710443
# 30040000000833
# 30000000730553 Action: extinguish Value: 5.679504440497321
# 30040000000833
# 30000000730553 Action: down Value: 4.856689867270929
# 30040000000833
# 30001000730553 Action: left Value: -0.7269023876404612
# 30040000000833
# 30000000730553 Action: extinguish Value: 6.94013985448664
# 30040000000833
# 30000000730553 Action: right Value: 7.234726602800271
# 30040000000833
# 30000100730553 Action: right Value: 5.0689653266331405
# 37001000000833
# 30000000730553 Action: right Value: 8.262665522471428
# 37000000000833
# 30000000730553 Action: left Value: 3.357536024983283
# 37000000000833
# 30000000730553 Action: down Value: 3.466141818181814
# 37000000000833
# 30000000730553 Action: extinguish Value: 11.658761006289286
# 37000000000833
# 30000000730553 Action: left Value: -2.706542283298094
# 37000000000833
# 30000000730553 Action: down Value: 1.2760616740088122
# 37000000000833
# 30000000730553 Action: down Value: -0.8454995004994996
# 37000000000833
# 30000000730553 Action: down Value: -0.08769854628920966
# 37000000000833
# 30000000730553 Action: extinguish Value: -0.05094467829224024
# 37000000000833
# 30000000730553 Action: left Value: -1.0859142114384726
# 37000000000833
# 30000000730553 Action: right Value: -6.2097982261640725
# 37000000000833
# 30000000730553 Action: right Value: -11.543019607843135
# 37000000000833
# 30000000730553 Action: extinguish Value: 3.4467894736842126
# 37000000000833
# 30000000730553 Action: down Value: 3.193727272727274
# 37000000000833
# 30000000730553 Action: left Value: 3.2340639534883753
# 37000000000833
# 30000000730553 Action: extinguish Value: 2.9296825396825446
# 37000000000833
# 30000000730553 Action: extinguish Value: 3.111730375426626
# 37000000000833
# 30000000730553 Action: up Value: 3.1975737704918075
# 37000000000833
# 30000000730553 Action: right Value: 3.20105434782609
# 37000000000833
# 30000000730553 Action: down Value: 3.134482352941179
# 37000000000833
# 30000000730553 Action: left Value: 3.1159759036144603
# 37000000000833
# 30000000730553 Action: down Value: 2.8827368421052686
# 37000000000833
# 30000000730553 Action: right Value: 2.7909866666666736
# 37000000000833
# 30000000730553 Action: up Value: 2.795903225806459
# 37000000000833
# 30000000730553 Action: right Value: 2.8053965517241464
# 37000000000833
# 30000000730553 Action: right Value: 3.059342857142865
# 37000000000833
# 30000000730553 Action: left Value: 3.680444444444454
# 37000000000833
# 30000000730553 Action: right Value: 5.721000000000009
# 37000000000833
# 30000000730553 Action: up Value: 3.0298750000000094
# 37000000000833
# 30000000730553 Action: extinguish Value: 6.966333333333343
# 37000000000833
# 30000000730553 Action: left Value: 6.957500000000009
# 37000000000833
# 30000000730553 Action: down Value: 6.932000000000009
# 37000000010033
# 30000700030553 Action: right Value: 11.59518277310921
# 37000000100033
# 30000700030553 Action: right Value: 12.95456012332986
# 37000001000033
# 30000700030553 Action: down Value: 10.427347159090862
# 37000010000033
# 30000700030553 Action: right Value: 8.53885245901637
# 37000000000033
# 30000700130553 Action: right Value: 11.613755044843034
# 37000000000033
# 30000701030553 Action: down Value: 14.07788391699091
# 37000000000033
# 30000710030553 Action: up Value: 14.393943262411307
# 37000000000033
# 30000100030553 Action: left Value: 8.412099937749673
# 37000100000033
# 30000000030553 Action: left Value: 8.618069904327303
# 37000010000033
# 30000000030553 Action: left Value: 8.50617064246146
# 37001000000033
# 30000000030553 Action: left Value: 9.435702280762179
# 37010000000033
# 30000000030553 Action: down Value: 9.942153565044729
# 37000000000033
# 30001000030553 Action: extinguish Value: 8.999615827075012
# 37000000000033
# 30000010030553 Action: left Value: 8.15280106162011
# 37000000000033
# 30000000030553 Action: up Value: 6.035015099681503
# 37000000000033
# 30000000030553 Action: left Value: 6.594590805717982
# 37000000000033
# 30000001030553 Action: left Value: 8.091969321439912
# 37000001000033
# 30000000030553 Action: left Value: 7.772531784474227
# 37000000100033
# 30000000030553 Action: right Value: 7.7773420646929345
# 37000000010033
# 30000000030553 Action: right Value: 10.038407936642944
# 37000000001033
# 30000000030553 Action: left Value: 9.61100730742023
# 37000000000133
# 30000000030553 Action: right Value: 10.375072034223459
# 37000000000033
# 30000000030153 Action: down Value: 11.119620289171152
# 37000000000033
# 30000000030513 Action: right Value: 5.940049253785308
# 37000000000033
# 30000000030553 Action: up Value: 5.9015558028072865
# 37000000000033
# 30000000030513 Action: down Value: 6.586204202142284
# 37000000000033
# 30000000030153 Action: left Value: 5.5801760583661295
# 37000000000033
# 30000000030553 Action: extinguish Value: 6.452966253244887
# 37000000000033
# 30000000030553 Action: extinguish Value: 3.969920005338254
# 37000000000033
# 30000000030553 Action: right Value: 3.7930954858669717
# 37000000000033
# 30000000030553 Action: right Value: 5.484075773745993
# 37000000000033
# 30000000030553 Action: extinguish Value: 5.659791148500368
# 37000000000033
# 30000000031553 Action: down Value: 5.736476278639174
# 37000000001033
# 30000000030553 Action: right Value: 5.5882458317177175
# 37000000010033
# 30000000030553 Action: right Value: 4.945277573529403
# 37000000100033
# 30000000030553 Action: extinguish Value: 4.775112637362632
# 37000001000033
# 30000000030553 Action: left Value: 4.246391025641025
# 37000000000033
# 30000000130553 Action: extinguish Value: 5.85050566037735
# 37000000000033
# 30000001030553 Action: left Value: 7.239325842696628
# 37000000000033
# 30000010030553 Action: right Value: 8.748102880658436
# 37000000000033
# 30000000030553 Action: right Value: 6.547974009900978
# 37000000000033
# 30000100030553 Action: left Value: 8.835085561497316
# 37000100000033
# 30000000030553 Action: extinguish Value: 5.5933766233766224
# 37000010000033
# 30000000030553 Action: down Value: 8.479434903047087
# 37000000000033
# 30000000030553 Action: up Value: 6.664497727272721
# 37000000000033
# 30000000030553 Action: down Value: 7.288940532081364
# 37000000000033
# 30000000030553 Action: down Value: 7.334090909090906
# 30000000000833
# 30000000730553 Action: up Value: 11.963101792402336
# 30000000000833
# 30000000730553 Action: up Value: 9.132195492816136
# 30000000000833
# 30000000730553 Action: right Value: 6.620776973207802
# 30000000000833
# 30000000730553 Action: left Value: 7.518969870403258
# 30000000000833
# 30000000730553 Action: down Value: 5.552342684742578
# 30000000000833
# 30000000730553 Action: right Value: 5.999331587144255
# 30000000000833
# 30000000730553 Action: up Value: 15.878201507570363
# 30000000000833
# 30000000730553 Action: up Value: 7.022926939552543
# 30000000000833
# 30000000730553 Action: down Value: 6.0404928806133436
# 30000000000833
# 30010000730553 Action: left Value: 7.839908631274828
# 30000000000833
# 30000000730553 Action: down Value: 4.74430970149252
# 30000000000833
# 30400000730553 Action: left Value: 4.2294050297815895
# 30000000000833
# 30400000730553 Action: up Value: 4.601068887206649
# 30000000000833
# 31400000730553 Action: right Value: 5.369458670988642
# 30000000000833
# 30400000730553 Action: down Value: 4.679381538461528
# 30000000000833
# 30400000730553 Action: down Value: 5.483857627118629
# 30000000000833
# 30400000730553 Action: up Value: 5.990863453815249
# 30000000000833
# 30400000730553 Action: extinguish Value: 6.1850982332155215
# 30000000000833
# 30401000730553 Action: down Value: 6.62544578313251
# 30000000000833
# 30410000730553 Action: right Value: 5.927471065989829
# 30010000000833
# 30400000730553 Action: extinguish Value: 6.279576361221763
# 30001000000833
# 30400000730553 Action: left Value: 6.298677637947702
# 30000000000833
# 30400100730553 Action: down Value: 5.483229007633575
# 30000100000833
# 30400000730553 Action: up Value: 5.619181076672093
# 30000010000833
# 30400000730553 Action: right Value: 5.127482866043593
# 30000001000833
# 30400000730553 Action: extinguish Value: 5.6031818181818
# 30000000000833
# 30400010730553 Action: up Value: 4.743650214592264
# 30000000000833
# 30400001730553 Action: right Value: 4.286256521739116
# 30000000000833
# 30400000130553 Action: left Value: 4.479590322580625
# 30000000000833
# 30400001030553 Action: down Value: 4.67567066895366
# 30000000000833
# 30400010030553 Action: right Value: 4.584367441860438
# 30000000100833
# 30400000030553 Action: extinguish Value: 4.7048395721924825
# 30000000000833
# 30400100030553 Action: up Value: 4.324264775413688
# 30000000000833
# 30401000030553 Action: right Value: 4.273199999999978
# 30000100000833
# 30400000030553 Action: down Value: 4.390364795918341
# 30000010000833
# 30400000030553 Action: right Value: 4.461549295774617
# 30001000000833
# 30400000030553 Action: right Value: 4.150942257217827
# 30000000000833
# 30400000030553 Action: up Value: 4.227188172042989
# 30000001000833
# 30400000030553 Action: left Value: 4.4262462686566835
# 30010000000833
# 30400000030553 Action: down Value: 4.240419203747051
# 30000000000833
# 30410000030553 Action: down Value: 4.2693101265822655
# 30000000000833
# 34100000030553 Action: down Value: 4.210674418604634
# 30000000000833
# 34000000030553 Action: right Value: 4.3199669421487386
# 30000000000833
# 34000000030553 Action: right Value: 4.286886363636355
# 30000000000833
# 34000000030553 Action: right Value: 3.9502499999999645
# 30000000000833
# 34000000030553 Action: up Value: -7.534423529411784
# 30000000000833
# 34000000030553 Action: extinguish Value: 4.304753623188384
# 30000000000833
# 34000000030553 Action: right Value: 4.344210526315783
# 31000000000833
# 30000700730553 Action: right Value: 9.636659397976517
# 30100000000833
# 30000700730553 Action: right Value: 11.173445548387077
# 30000000000833
# 31000700730553 Action: extinguish Value: 8.331305919347564
# 30000000000833
# 30100700730553 Action: up Value: 9.995147037956714
# 30000000000833
# 30000700730553 Action: right Value: 5.569861616161642
# 30000000000833
# 30000700730553 Action: right Value: 6.431929858963744
# 30000000000833
# 30001700730553 Action: up Value: 6.57165794768607
# 30000000000833
# 30010700730553 Action: extinguish Value: 5.301765795030076
# 30000000000833
# 30100700730553 Action: right Value: 4.196410805916075
# 30000000000833
# 30000700730553 Action: right Value: 6.5390616322383694
# 30001000000833
# 30000700730553 Action: right Value: 7.519253640365681
# 30010000000833
# 30000700730553 Action: right Value: 4.138460943856779
# 30100000000833
# 30000700730553 Action: down Value: 3.975697817189619
# 31000000000833
# 30000700730553 Action: right Value: 3.312487827715349
# 30000000000833
# 31000700730553 Action: right Value: 3.7195101636093115
# 30000000000833
# 30000700730553 Action: extinguish Value: 4.354458043826824
# 30000100000833
# 30000700730553 Action: down Value: 8.427708193579267
# 30000010000833
# 30000700730553 Action: right Value: 3.6879351851851663
# 30000000000833
# 30000710730553 Action: right Value: 2.5858163265306233
# 30000000000833
# 30000701730553 Action: right Value: 2.593333333333345
# 30000000000833
# 30000700130553 Action: extinguish Value: 3.3884899536321345
# 30000000000833
# 30000701030553 Action: up Value: 3.4212727272727124
# 30000000100833
# 30000700030553 Action: left Value: 3.4270149253731175
# 30000000000833
# 30000710030553 Action: left Value: 3.4813846153846
# 30000000010833
# 30000700030553 Action: down Value: 3.4998598726114465
# 30000000001833
# 30000700030553 Action: down Value: 2.2655000000000136
# 30000000000833
# 30000700031553 Action: up Value: 2.256733333333347
# 37000010000833
# 30000000730553 Action: left Value: 10.771878514406655
# 37000001000833
# 30000000730553 Action: right Value: 16.1084154998777
# 37000000100833
# 30000000730553 Action: right Value: 19.329786549089544
# 37000000010833
# 30000000730553 Action: right Value: 21.23314179747379
# 37000000000833
# 30000001730553 Action: up Value: 13.952553588370955
# 30000000000833
# 30000000730553 Action: up Value: 5.720433288948079
# 30000000000833
# 31000000730553 Action: right Value: 12.617650052748216
# 31000000000833
# 30000000730553 Action: extinguish Value: 14.671739946189614
# 30100000000833
# 30000000730553 Action: right Value: 14.990918542548023
# 30010000000833
# 30000000730553 Action: up Value: 17.728580488292142
# 30000000000833
# 30000000730553 Action: up Value: 18.06671284568143
# 30000000000833
# 30001000730553 Action: right Value: 19.192619866427677
# 30000000000833
# 30000100730553 Action: up Value: 19.837491079787814
# 30000000000833
# 30000010730553 Action: right Value: 19.230005578635534
# 30000100000833
# 30000000730553 Action: right Value: 20.877047769641315
# 30000000000833
# 30010000730553 Action: right Value: 18.721528564567016
# 30010000000833
# 30000000730553 Action: right Value: 18.81274881770441
# 30000000000833
# 30100000730553 Action: up Value: 16.282528677178618
# 31000000000833
# 30000000730553 Action: up Value: 6.080050640102979
# 30000000000833
# 30000000730553 Action: extinguish Value: 16.413014500306552
# 30001000000833
# 30000000730553 Action: right Value: 19.763724239822263
# 30000000000833
# 30000000730553 Action: extinguish Value: 14.411118065023663
# 30000000000833
# 30000000730553 Action: left Value: 8.363499999999982
# 30000000000833
# 30000000730553 Action: right Value: 7.40489475133051
# 30000000000833
# 30010000730553 Action: down Value: 7.261399361896079
# 30000000000833
# 30100000730553 Action: right Value: 6.385713476541604
# 30100000000833
# 30000000730553 Action: extinguish Value: 7.352225174600576
# 30010000000833
# 30000000730553 Action: down Value: 6.5443090693889285
# 30001000000833
# 30000000730553 Action: left Value: 6.020258287122547
# 30000100000833
# 30000000730553 Action: up Value: 9.167085124826562
# 30000000000833
# 30000100730553 Action: right Value: 7.478839461713358
# 30000000000833
# 30001000730553 Action: right Value: 7.548970604625195
# 30000000000833
# 30000000730553 Action: up Value: 7.970101986434082
# 30000000000833
# 30000000730553 Action: down Value: 8.573536517124884
# 31000000000833
# 30000000730553 Action: right Value: 6.021731001545151
# 30000000000833
# 31000000730553 Action: down Value: 6.369355198176492
# 30000000000833
# 30000000730553 Action: left Value: 6.276159178659144
# 30000000000833
# 30000000730553 Action: extinguish Value: 6.907947031853337
# 30000000000833
# 30000000730553 Action: right Value: 11.13110399717014
# 30100000000833
# 30000000730553 Action: right Value: 5.719646383467274
# 30000000000833
# 30000000730553 Action: up Value: 6.59076451366194
# 37000000000833
# 30000000130553 Action: down Value: 6.78702474569945
# 37000000000833
# 30000001030553 Action: up Value: 5.794505949211338
# 37000001000833
# 30000000030553 Action: right Value: 6.391870200339261
# 37000100000833
# 30000000030553 Action: right Value: 4.6758680837931905
# 37001000000833
# 30000000030553 Action: left Value: 3.2219790793761733
# 37000000000833
# 30001000030553 Action: down Value: 2.5798373593857655
# 37000000000833
# 30010000030553 Action: left Value: 3.8469775388918097
# 37010000000833
# 30000000030553 Action: right Value: 3.4590753683415256
# 37000000000833
# 30000000030553 Action: down Value: 2.054546897546884
# 37000000000833
# 30010000030553 Action: left Value: 3.3210044150110374
# 37000000000833
# 30001000030553 Action: right Value: 2.658752802843861
# 37001000000833
# 30000000030553 Action: left Value: 3.1275815665488715
# 37010000000833
# 30000000030553 Action: down Value: 3.388634952847077
# 37100000000833
# 30000000030553 Action: up Value: 4.98532357879586
# 31000000000833
# 30000000030553 Action: left Value: 4.602841048034947
# 30100000000833
# 30000000030553 Action: up Value: 4.389451598773539
# 30000000000833
# 30100000030553 Action: extinguish Value: 4.016781077000499
# 30000000000833
# 31000000030553 Action: down Value: 5.296488060781472
# 30000000000833
# 30000000030553 Action: extinguish Value: 6.027575050709934
# 30000000000833
# 30000000030553 Action: right Value: 6.05122827687776
# 30000000000833
# 30000000030553 Action: extinguish Value: 6.286510047708564
# 30000000000833
# 31000000030553 Action: down Value: 5.369403946928263
# 30000000000833
# 30100000030553 Action: extinguish Value: 5.194503649635026
# 30000000000833
# 30010000030553 Action: right Value: 4.892582412143179
# 30000000000833
# 30000000030553 Action: up Value: 5.65281286549705
# 30100000000833
# 30000000030553 Action: left Value: 5.49007800678315
# 31000000000833
# 30000000030553 Action: up Value: 5.545046884016065
# 30010000000833
# 30000000030553 Action: up Value: 7.303850936444521
# 30001000000833
# 30000000030553 Action: extinguish Value: 8.870542687556048
# 30000000000833
# 30001000030553 Action: right Value: 6.386556629458183
# 30000100000833
# 30000000030553 Action: right Value: 14.124501098257461
# 30000010000833
# 30000000030553 Action: right Value: 16.527576449488734
# 30000000000833
# 30000010030553 Action: right Value: 15.533467309112634
# 30000000000833
# 30000000030553 Action: up Value: 9.88163287780283
# 30000001000833
# 30000000030553 Action: right Value: 18.869342391346446
# 30000000000833
# 30000001030553 Action: up Value: 18.69754051030515
# 30000000000833
# 30000100030553 Action: up Value: 12.60468131976686
# 30000000000833
# 30000000030553 Action: down Value: 4.4676951992753215
# 30000000000833
# 30000000030553 Action: left Value: 4.587740092921543
# 30000000000833
# 30000000030553 Action: right Value: 5.690382885211962
# 30000000000833
# 30000000030553 Action: left Value: 5.8416831460673375
# 30000000000833
# 30000000030553 Action: left Value: 4.913301041195078
# 30000000000833
# 30000000030553 Action: left Value: 4.948870528109008
# 30000000000833
# 30000000030553 Action: up Value: 5.102082582582558
# 30000000000833
# 30001000030553 Action: left Value: 5.406122492080223
# 30000000000833
# 30010000030553 Action: left Value: 5.151913539967351
# 30000000000833
# 30000100030553 Action: down Value: 6.8279413434247695
# 30000100000833
# 30000000030553 Action: extinguish Value: 6.669552517985606
# 30000010000833
# 30000000030553 Action: right Value: 7.19009904333146
# 30000001000833
# 30000000030553 Action: right Value: 7.521461384820234
# 30000000000833
# 30000001030553 Action: up Value: 6.835880818752046
# 30000000000833
# 30000000130553 Action: extinguish Value: 7.154422607879906
# 30000000100833
# 30000000030553 Action: right Value: 7.592049207673064
# 30000000010833
# 30000000030553 Action: right Value: 7.942849765258235
# 30000000001833
# 30000000030553 Action: left Value: 8.118710560625809
# 37100000000833
# 30000700730553 Action: left Value: 13.263522768761234
# 30000000000833
# 30010700730553 Action: down Value: 13.71527348792728
# 30010000000833
# 30000700730553 Action: right Value: 11.990473038152373
# 30000000000833
# 30000700730553 Action: up Value: 4.232084666406545
# 30000000000833
# 30000700730553 Action: down Value: 3.967414239482197
# 30000000000833
# 30000700730553 Action: right Value: 3.9160945343000697
# 30000000000833
# 30000700730553 Action: right Value: 4.534344025661576
# 30000000000833
# 30000700730553 Action: extinguish Value: 4.581073587385006
# 30000000000833
# 30000700730553 Action: right Value: 5.0675284552845445
# 30000000000833
# 30000700730553 Action: right Value: 5.833698818897632
# 30000000000833
# 30000700730553 Action: left Value: 5.353404015056477
# 30000000000833
# 30000700730553 Action: right Value: 5.988897959183663
# 37000100000833
# 30000000730553 Action: right Value: 9.518207183333974
# 37010000000833
# 30000000730553 Action: down Value: 8.642493178160223
# 37100000000833
# 30000000730553 Action: left Value: 9.010869323201984
# 37000000000833
# 31000000730553 Action: right Value: 10.770222471910078
# 31000000000833
# 30000000730553 Action: up Value: 9.663509920444815
# 30000000000833
# 31000000730553 Action: right Value: 7.780771001566832
# 30000000000833
# 30100000730553 Action: extinguish Value: 13.903274090594477
# 30100000000833
# 30000000730553 Action: down Value: 9.475970968830891
# 30010000000833
# 30000000730553 Action: down Value: 13.019552913020727
# 30000000000833
# 30010000730553 Action: down Value: 12.291051673824466
# 30000010000833
# 30000000730553 Action: right Value: 21.493201275275094
# 30000000000833
# 30000000730553 Action: up Value: 16.600287378109158
# 30000000000833
# 30000000730553 Action: up Value: 12.386772861999788
# 30000000000833
# 30000000730553 Action: left Value: 9.004168402426703
# 30000000000833
# 30000000730553 Action: right Value: 8.182199407407346
# 30000000000833
# 30000000730553 Action: extinguish Value: 8.485427855418166
# 30000000000833
# 30000000730553 Action: extinguish Value: 8.367324844120457
# 30000000000833
# 30000000730553 Action: up Value: 7.2233481657608625
# 30000000000833
# 30000000730553 Action: right Value: 9.562004043925375
# 30000001000833
# 30000000730553 Action: right Value: 22.34236322151411
# 30000000100833
# 30000000730553 Action: right Value: 23.280850684952277
# 30000000000833
# 30000000130553 Action: right Value: 19.40701472738435
# 30000000100833
# 30000000030553 Action: right Value: 19.415352222268616
# 30000000000833
# 30000000030553 Action: down Value: 6.022894247038893
# 30000000000833
# 30000000030553 Action: right Value: 4.304008704061874
# 30000000000833
# 30000010030553 Action: up Value: 6.480752503576525
# 37010000000833
# 30000000730553 Action: down Value: 16.790263981192936
# 37001000000833
# 30000000730553 Action: left Value: 15.408044620790841
# 37000100000833
# 30000000730553 Action: left Value: 12.579047259599603
# 37000000000833
# 30001000730553 Action: up Value: 14.329461063089878
# 37000000000833
# 30000100730553 Action: left Value: 11.62593735003995
# 37000010000833
# 30000000730553 Action: left Value: 10.577445935319002
# 37000001000833
# 30000000730553 Action: extinguish Value: 11.537512522736735
# 37000000000833
# 30000010730553 Action: up Value: 8.930871214438636
# 37000000000833
# 30000000730553 Action: left Value: 6.120110441054818
# 37000000000833
# 30000000730553 Action: right Value: 10.054605780410776
# 37000000000833
# 30000000730553 Action: right Value: 9.601985793166893
# 37000000000833
# 30000000730553 Action: up Value: 13.69547477781331
# 37100000000833
# 30000000730553 Action: left Value: 19.368165931011735
# 30000000000833
# 30000000730553 Action: extinguish Value: 5.820045662100436
# 30000000000833
# 30000000730553 Action: left Value: 5.809727272727261
# 30000000000833
# 30000000730553 Action: left Value: 1.500802761341232
# 30000000000833
# 30000000730553 Action: up Value: -16.213791208791207
# 30000000000833
# 30000000730553 Action: right Value: 8.765428139183042
# 37000000000833
# 30000000730553 Action: left Value: 8.123094460901916
# 37000000000833
# 30040000730553 Action: extinguish Value: 8.855409711925413
# 37000000000833
# 30040000730553 Action: left Value: 5.658058896982296
# 37000000000833
# 30040000730553 Action: left Value: 11.806318874560365
# 37000000000833
# 30040000730553 Action: down Value: 4.352075918079094
# 37000000000833
# 30040000730553 Action: down Value: 3.4684584472389024
# 37000000000833
# 30040000730553 Action: up Value: 6.492449076127134
# 37040000000833
# 30010000730553 Action: right Value: 10.273995011707216
# 37040000000833
# 30000000730553 Action: right Value: 7.352598279945166
# 37040000000833
# 30000000730553 Action: up Value: 9.506270247933877
# 37040000000833
# 30000000730553 Action: right Value: 6.2711965326340415
# 37040000000833
# 30000000730553 Action: right Value: 6.951001497902931
# 37040000000833
# 30000000730553 Action: down Value: 8.359618618618596
# 37040000000833
# 30000000730553 Action: up Value: 10.64670280862179
# 37040000000833
# 30000010730553 Action: right Value: 13.91935365086024
# 37040000000833
# 30000100730553 Action: right Value: 11.762476705962348
# 37040010000833
# 30000000730553 Action: down Value: 11.568689698890632
# 37040100000833
# 30000000730553 Action: right Value: 8.85273161033794
# 37041000000833
# 30000000730553 Action: down Value: 8.318419734904252
# 37040000000833
# 30001000730553 Action: right Value: 11.124306150793652
# 37410000000833
# 30000000730553 Action: up Value: 5.897684469515192
# 37400000000833
# 30010000730553 Action: right Value: 8.133826196473517
# 37400000000833
# 30000000730553 Action: up Value: 5.900788602941161
# 37400000000833
# 30000000730553 Action: extinguish Value: 8.565392294220644
# 37400000000833
# 30000000730553 Action: left Value: 6.144070063694257
# 37400000000833
# 30000000730553 Action: up Value: 7.009324246771858
# 37400000000833
# 30000000730553 Action: left Value: 7.472607902735542
# 37400000000833
# 30000000730553 Action: right Value: 9.536885017421593
# 37400000000833
# 30000000730553 Action: left Value: 4.0958632478632495
# 37400000000833
# 30000000730553 Action: extinguish Value: 1.66178571428573
# 37400000000833
# 30000000730553 Action: extinguish Value: 5.482559322033914
# 37400000000833
# 30000000730553 Action: down Value: 4.007014957264967
# 37400000000833
# 30000000730553 Action: extinguish Value: 6.475804878048798
# 37400000000833
# ...
# 30000000000033
# 30000100030563 Action: left Value: -19.055958333333308
# 30000000000033
# 30000010030563 Action: right Value: 0.0
# 30000010000033
# 30000000030563 Action: left Value: 0.0
# 30000001000033
# 30000000030563 Action: down Value: 0.0
# 30000000100033
# 30000000030563 Action: right Value: 0.0
# 30000000000033
# 30000000130563 Action: right Value: 0.0
# 30000000000033
# 34000000030563 Action: left Value: 37.90288297872362
# 30000000000033
# 34000000030563 Action: down Value: 37.813585365853896
# 30000000000033
# 34000000030563 Action: down Value: 37.770526315789716
# 30000000000033
# 34000000030563 Action: up Value: 37.605210526316064
# 30000000000033
# 34000000030563 Action: down Value: 37.604215909091195
# 30000000000033
# 34000000030563 Action: left Value: 37.55585964912308
# 37040000000833
# 30000000030553 Action: right Value: 0.44056557377047645
# 37040000000833
# 30000000030553 Action: left Value: 0.3653719008264309
# 37040000000833
# 30000000030553 Action: up Value: 0.2889333333333168
# 37040000000833
# 30000000030553 Action: extinguish Value: 0.21121848739494006
# 37040000000833
# 30000000030553 Action: right Value: 0.052666666666648806
# 37040000000833
# 30000000030553 Action: right Value: 0.0
# 37040000000833
# 30000000030553 Action: right Value: 0.0
# 37040000000833
# 30000000030553 Action: extinguish Value: -3.1848595121951275
# 37040000000833
# 30000000030553 Action: up Value: 0.0
# 37040000000833
# 30000000030553 Action: up Value: 0.0
# 37040000000833
# 30000000030553 Action: right Value: 0.0
# 37040000000833
# 30000000030553 Action: right Value: -19.024184210526347
# 37040000000833
# 30000000030553 Action: up Value: -19.038219512195145
# 37040000000833
# 30000000030553 Action: right Value: 0.0
# 37040000000833
# 30000000030553 Action: right Value: 0.0
# 37040000000833
# 30000000030553 Action: right Value: 0.0
# 37040000000833
# 30000000030553 Action: up Value: 0.0
# 37040000000833
# 30000000030553 Action: left Value: 0.0
# 37040000000833
# 30000000030553 Action: right Value: 0.0
# 37040000000833
# 30000000030553 Action: right Value: 0.0
# 37000000000033
# 30000000030553 Action: right Value: 14.580866336633658
# 37000000000033
# 30000000030563 Action: down Value: 23.471571428571156
# 30000000000833
# 30040000030553 Action: extinguish Value: 8.809927536231877
# 30000000000833
# 30040000030553 Action: down Value: 8.703166666666663
# 30000000000833
# 30040000030553 Action: down Value: 8.677555555555553
# 30000000000833
# 30040000030553 Action: extinguish Value: 8.643499999999996
# 37000000000033
# 30000000030563 Action: left Value: 23.1767391304346
# 37000000000033
# 30000000030563 Action: left Value: 23.11619047619029
# 37000000000033
# 30000000031563 Action: right Value: 31.399584362139954
# 37000000000033
# 30000000030163 Action: extinguish Value: 31.341342436974827
# 31000000000833
# 30000000730563 Action: right Value: 25.173918032786776
# 30100000000833
# 30000000730563 Action: left Value: 25.162333333333223
# 30000000000833
# 30100000730563 Action: down Value: 25.04308695652163
# 30000000000833
# 30000000730563 Action: left Value: 24.965722222222105
# 30000000000833
# 30000000730563 Action: left Value: 24.9637894736841
# 30000000000833
# 31000000730563 Action: extinguish Value: 24.7397818181817
# 30000000000033
# 30000000030563 Action: up Value: 29.81928888888871
# 30000000000033
# 30000000030563 Action: up Value: 29.294980392156692
# 30000000000033
# 30000000030563 Action: left Value: 30.145037735848856
# 30000000000033
# 30000000030563 Action: extinguish Value: 30.13047058823509
# 30000000000033
# 30000000030563 Action: down Value: 30.072333333333123
# 30000000000033
# 30000000030563 Action: right Value: 29.998499999999783
# 30000000000033
# 30000000030563 Action: up Value: 29.96424999999979
# 30000000000033
# 30000000030563 Action: up Value: 39.10375000000034
# 30000000000033
# 30000000030563 Action: up Value: 39.09100000000034
# 30000000000033
# 30000000031563 Action: extinguish Value: 39.05766666666701
# 30000000000033
# 30000000030563 Action: down Value: 31.283111111111
# 30000000000033
# 30000000030563 Action: up Value: 31.259108433734827
# 30000000000033
# 30000000030563 Action: down Value: 31.104882352941058
# 30000000000033
# 30000000030563 Action: right Value: 31.08599999999988
# 30000000000033
# 30000000030563 Action: up Value: 31.064666666666547
# 30000000000033
# 30000000030563 Action: right Value: 30.951111111110958
# 30000000000033
# 30000000030563 Action: up Value: 30.81649999999987
# 30000000000033
# 30000000030563 Action: right Value: 30.79099999999987
# 30000000000033
# 30100000030563 Action: down Value: 39.50085714285747
# 30000000000033
# 30000000030563 Action: down Value: 32.97477483443718
# 30000000000033
# 30000000030563 Action: right Value: 32.93378082191789
# 30000000000033
# 30000000030563 Action: up Value: 32.698927710843485
# 30000000000033
# 30000000030563 Action: left Value: 32.782103646833214
# 30000000000033
# 30000010030563 Action: down Value: 32.52965555555569
# 30000000000033
# 30000000030563 Action: left Value: 32.551928000000146
# 30000000000033
# 30000000030563 Action: extinguish Value: 32.38301030927849
# 30000000000033
# 30000000030563 Action: left Value: 32.35021917808235
# 30000010000033
# 30000000030563 Action: extinguish Value: 32.15374324324343
# 30000100000033
# 30000000030563 Action: up Value: 32.04645714285732
# 30000000000033
# 30000100030563 Action: right Value: 31.9952500000002
# 34000000000033
# 30000000030563 Action: extinguish Value: 0.0
# 34000000000033
# 31000000030563 Action: right Value: 0.0
# 34000000000033
# 30000000030563 Action: down Value: 0.0
# 30000000000033
# 30000000030563 Action: down Value: 21.736863157894565
# 30000000000033
# 30000000030563 Action: up Value: 39.41279310344842
# 30000000000033
# 30000000030563 Action: right Value: 38.81800000000028
# 30000000000033
# 30000000030553 Action: left Value: 16.250711340206134
# 30000000000033
# 30000000030553 Action: right Value: 16.215733333333283
# 30000000000033
# 30000000030553 Action: extinguish Value: 16.218797752808957
# 30000000000033
# 30000000030553 Action: down Value: 16.24140624999995
# 30000000000033
# 30000000030153 Action: up Value: 15.998290322580589
# 30000000000133
# 30000000030553 Action: right Value: 15.990124999999942
# 30000000001033
# 30000000030553 Action: up Value: 15.772548387096716
# 37000000000033
# 30000000030563 Action: up Value: 33.98196907216505
# 37000000000033
# 30000000030563 Action: extinguish Value: 33.9558006993009
# 31000000000033
# 30000000030563 Action: right Value: 33.82357142857158
# 30100000000033
# 30000000030563 Action: down Value: 33.768793814433145
# 30000000000033
# 30000000030563 Action: down Value: 33.67810937500016
# 37000000000033
# 30000000030563 Action: extinguish Value: 31.292681034482865
# 30000000000033
# 34100000030563 Action: left Value: 38.783999999999935
# 30000000000033
# 30010000730563 Action: up Value: 25.421144927536016
# 30010000000033
# 30000000730563 Action: left Value: 25.422411764705668
# 30000000000033
# 30000000730563 Action: down Value: 25.717257142856905
# 30000000000033
# 30000000730563 Action: left Value: 25.563312499999743
# 30000000000033
# 30000000730563 Action: extinguish Value: 25.50394999999974
# 30000000000033
# 30000000730563 Action: extinguish Value: 25.382999999999736
# 30000000000033
# 30000000030563 Action: right Value: 28.99213888888873
# 30000000000033
# 30000000030563 Action: right Value: 28.93599999999984
# 30000000000033
# 30000000030563 Action: right Value: 28.75772499999983
# 30000000000033
# 30000000030563 Action: right Value: 28.710138888888714
# 30000000000033
# 30000000030563 Action: extinguish Value: 28.68297999999983
# 30000000000033
# 30000000030563 Action: left Value: 30.765333333333192
# 30000000000033
# 30000000030563 Action: down Value: 29.06027586206885
# 30000000000033
# 30000000030563 Action: extinguish Value: 29.112864864864754
# 30000000000033
# 30000000030563 Action: right Value: 28.985446808510517
# 30000000000033
# 30000000030563 Action: up Value: 28.96255263157882
# 30000000000033
# 30000000030563 Action: down Value: 28.9569318181817
# 30000000000033
# 30000000030563 Action: down Value: 28.945208333333216
# 30000000000033
# 30000000030563 Action: down Value: 28.82999999999987
# 30000000000033
# 30000000030563 Action: up Value: 25.704299999999808
# 30000000000033
# 30000000030563 Action: extinguish Value: 31.029169172932406
# 30000000000033
# 30000000030563 Action: up Value: 30.994147704590926
# 30000000000033
# 30000000030563 Action: extinguish Value: 30.34256321839082
# 30000000000033
# 30000000030563 Action: left Value: 30.32050000000002
# 30000000000033
# 30000000030563 Action: up Value: 30.32000000000001
# 30000000000033
# 30000000030563 Action: right Value: 30.318722222222235
# 30000000000033
# 30000000030563 Action: left Value: 30.31858333333335
# 30000000000033
# 30000000030563 Action: down Value: 30.316500000000012
# 37000000000833
# 30000000030563 Action: down Value: 11.00699999999999
# 37040000000833
# 30000000030553 Action: down Value: 9.22910687022901
# 37040000000833
# 30000000030553 Action: down Value: 9.257584615384618
# 37040000000833
# 30000000030553 Action: left Value: 9.286511627906979
# 37040000000833
# 30000000030553 Action: extinguish Value: 9.377285714285717
# 37040000000833
# 30000000030553 Action: down Value: 9.061878080415068
# 37040000000833
# 30000000030553 Action: right Value: 9.029164496230283
# 37040000000833
# 30000000030553 Action: left Value: 9.015497826086955
# 37040000000833
# 30000000030553 Action: left Value: 8.963389328063254
# 37040000000833
# 30000000030553 Action: down Value: 8.381458333333345
# 37040000000833
# 30000000030553 Action: right Value: 8.13740000000001
# 37040000000833
# 30000000030553 Action: left Value: 8.107500000000012
# 37040000000833
# 30000000030553 Action: down Value: 8.082000000000013
# 37000000100033
# 30000000030563 Action: right Value: 23.431976190476053
# 37000000010033
# 30000000030563 Action: down Value: 23.3493685847588
# 37000000000033
# 30000000130563 Action: right Value: 22.974930434782458
# 30000000000033
# 30000000030563 Action: right Value: 38.63081818181839
# 37000000000033
# 30000000030563 Action: down Value: 18.57981203007498
# 37000000000033
# 30000000030563 Action: down Value: 18.462449999999812
# 37000000000033
# 30000000030563 Action: left Value: 18.4854545454543
# 37000000000033
# 30000000030563 Action: left Value: 18.365674999999786
# 37000000000033
# 30000000030563 Action: right Value: 18.48319999999976
# 37000000000033
# 30000000030563 Action: right Value: 18.58076190476166
# 37000000000033
# 30000000030563 Action: right Value: 18.607099999999754
# 37000000000033
# 30000000030563 Action: up Value: 18.550685714285457
# 37000000000033
# 30000000030563 Action: down Value: 18.38009803921542
# 37040000000833
# 30000000730553 Action: left Value: 13.339250000000003
# 30000000000033
# 30000000030563 Action: right Value: 30.707899999999842
# 30000000000033
# 30000000030563 Action: extinguish Value: 30.556999999999835
# 30000000000033
# 30000010030563 Action: left Value: 30.837000000000184
# 30000000000033
# 30000100030563 Action: down Value: 30.803000000000182
# 37000000000833
# 30000000730553 Action: up Value: 16.190797297297294
# 37000000000033
# 30000000030563 Action: up Value: 18.020612903225636
# 30000000000033
# 30000000030563 Action: up Value: 39.401596491228226
# 30000000000033
# 30000000030563 Action: up Value: 39.24250000000019
# 30000000000033
# 30000000030563 Action: extinguish Value: 39.23975652173928
# 30000000000033
# 30000000030563 Action: down Value: 39.21883132530137
# 30000000000033
# 30000000030563 Action: left Value: 39.18041739130454
# 30000000000033
# 30000000030163 Action: up Value: 38.877906976744384
# 30000000000133
# 30000000030563 Action: down Value: 38.82470588235315
# 37000000000833
# 30000000730553 Action: up Value: 17.855710843373398
# 37000000000833
# 30000000730553 Action: right Value: 17.330438596491135
# 37000000000833
# 30000000730553 Action: up Value: 17.74795209580829
# 37000000000133
# 30000000030563 Action: extinguish Value: 31.505978091872763
# 37000000001033
# 30000000030563 Action: up Value: 31.27853508771934
# 37000000010033
# 30000000030563 Action: down Value: 30.629297297297313
# 37000000100033
# 30000000030563 Action: left Value: 30.560000000000027
# 37000001000033
# 30000000030563 Action: left Value: 30.50455000000003
# 37000010000033
# 30000000030563 Action: extinguish Value: 30.453428571428606
# 30000000000033
# 30000000030563 Action: down Value: 28.498988372092843
# 30000000000033
# 30000000030563 Action: up Value: 28.49896124030989
# 30000000000033
# 30000000030563 Action: down Value: 28.372245059288343
# 30000000000033
# 30000000030563 Action: up Value: 28.36532067510528
# 37000000000833
# 30000000730553 Action: up Value: 6.763395393474078
# 37000000000833
# 30000000730553 Action: down Value: 6.750169590643263
# 37000000000833
# 30000000730553 Action: left Value: 6.738253164556946
# 37000000000833
# 30000000730553 Action: extinguish Value: 6.669177664974609
# 37000000000833
# 30000000730553 Action: up Value: 6.317589743589727
# 37000000000833
# 30000000730553 Action: extinguish Value: 6.312315789473666
# 37000000000833
# 30000000730553 Action: up Value: 6.303694444444425
# 37000000000833
# 30000000730553 Action: left Value: 6.258181818181798
# 37000000000833
# 30000000730553 Action: up Value: 6.261285714285694
# 37000000000833
# 30000000730553 Action: right Value: 6.271733333333314
# 37000000000833
# 30000000730553 Action: down Value: 6.265241379310326
# 37000000000833
# 30000000730553 Action: left Value: 6.199797297297275
# 37000000000833
# 30000000730553 Action: right Value: 6.186493506493485
# 30000000000033
# 30000000030563 Action: extinguish Value: 23.089888888888684
# 30000000000033
# 30000000030563 Action: right Value: 21.849833333333127
# 30000000000033
# 30000000030563 Action: right Value: 21.50619999999979
# 30000000000033
# 30000000030563 Action: left Value: 20.990999999999794
# 30000000000033
# 30000000030563 Action: extinguish Value: 20.115999999999797
# 30000000000033
# 30000000730563 Action: up Value: 24.598504065040466
# 30000000000033
# 30000000730563 Action: up Value: 24.52558964143408
# 30000000000033
# 31000000730563 Action: left Value: 24.65074558303862
# 31000000000033
# 30000000730563 Action: down Value: 24.646044444444204
# 30000000000033
# 30100000730563 Action: right Value: 24.645499999999753
# 30010000000033
# 30000000730563 Action: right Value: 24.689419354838464
# 30000000000033
# 30000100730563 Action: right Value: 24.742185185184933
# 30000000000033
# 30000010730563 Action: right Value: 24.75942307692282
# 30000000000033
# 30000001730563 Action: right Value: 24.778079999999747
# 30000000000033
# 30000000130563 Action: right Value: 24.691390243902198
# 34010000000033
# 30000000030563 Action: up Value: 0.0
# 34000000000033
# 30000100030563 Action: up Value: 0.0
# 34000000000033
# 30000010030563 Action: left Value: 0.0
# 34000000000033
# 30000001030563 Action: up Value: -15.778588235294164
# 34000001000033
# 30000000030563 Action: up Value: -17.387517171717196
# 34000010000033
# 30000000030563 Action: up Value: 0.0
# 34000100000033
# 30000000030563 Action: up Value: 0.0
# 34000000100033
# 30000000030563 Action: right Value: 0.0
# 34000000000033
# 30000000130563 Action: right Value: 0.0
# 34000000000033
# 30000000030563 Action: right Value: 0.0
# 34000000000033
# 30000000030563 Action: up Value: 0.0
# 34000000000033
# 30000000030563 Action: up Value: 0.0
# 34000000000033
# 30000000030563 Action: right Value: 0.0
# 30000000000833
# 30000000730563 Action: right Value: 0.0
# 30000000000833
# 30000000730563 Action: up Value: 0.0
# 30000000000833
# 30000000730563 Action: down Value: -16.978999999999967
# 30000000000833
# 30000000730563 Action: left Value: -17.427479999999967
# 30000000000833
# 30000000730563 Action: up Value: 0.0
# 30000000000833
# 30000000730563 Action: up Value: 0.0
# 30000000000033
# 30000000030553 Action: up Value: 14.386762886597866
# 30000000000033
# 30000000030553 Action: up Value: 14.346989583333261
# 30000000000033
# 30000000030553 Action: up Value: 14.306389473684138
# 30000000000033
# 30000000030563 Action: right Value: 0.0
# 30000000000033
# 30000000030563 Action: up Value: 0.0
# 30000000000033
# 30000000030563 Action: left Value: 0.0
# 30000000000033
# 30000000030563 Action: left Value: 0.0
# 30000000000033
# 30000000030563 Action: right Value: -10.08625925925936
# 30000000000033
# 30000000030563 Action: right Value: 0.0
# 30000000000033
# 30000000030563 Action: right Value: 0.0
# 30000000000033
# 30000000030563 Action: right Value: 0.0
# 30000000000033
# 30000000030163 Action: right Value: 0.0
# 30000000000033
# 30000000031563 Action: up Value: 0.0
# 30000000000033
# 30000000030563 Action: up Value: 0.0
# 30000000000033
# 30000000030563 Action: right Value: 0.0

# %%
#load the value function

fname = "D:\\2023-2024\\RNN\\Sokoban\\Results\\Chapter 0\\Level 3\\MC_first_100000_episodes_ok.bin"
with open(fname, 'rb') as handle:
    V = pickle.load(handle)

# %%
def greedy_policy_pi(V,s):
    #.9 prob of greedy action
    #.1 prob of random action

    if s not in V:
        V[s] = np.zeros(env.action_space.n)
    r_choice = .2
    if np.random.random() < r_choice:
        return np.random.choice(np.arange(env.action_space.n))
    else:
        max_val = np.max(V[s])
         #find all actions that have the max value and choose one at random
        max_actions = np.argwhere(V[s] == max_val).flatten()
        return np.random.choice(max_actions)

# %%
for i in range(1000):
    time.sleep(1)
    _ = env.reset()
    state = env.unwrapped.serialize_state()
    st_time = time.time()
    done = False
    t= 0
    last_reward = 0
    last_time = time.time()
    last_state = state
    rendered_frame = 0
    while True:
        if time.time() - st_time < .2:
            env.render()
            rendered_frame += 1
            time.sleep(1/144)
            if (time.time() - last_time) > 1:
                print(f'\rFPS: {rendered_frame}',end='')
                rendered_frame = 0
                last_time = time.time()
            continue
        st_time = time.time()
        action_time = time.time()
        action = greedy_policy_pi(V,state)
        
        state, reward, done, info = env.step(action)
        state = env.unwrapped.serialize_state()
        #print(f'{ACTION_LOOKUP[action]} state change: {last_state != state}',end=' ')
        last_state = state
        last_reward = reward
        t += 1
        if done or t > 150:
            env.render()
            break
        env.render()
# Out:
# FPS: 30
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\2023-2024\RNN\Sokoban\Sokoban_MC_P.ipynb Cell 11 line 1
#      <a href='vscode-notebook-cell:/d%3A/2023-2024/RNN/Sokoban/Sokoban_MC_P.ipynb#X13sZmlsZQ%3D%3D?line=11'>12</a> while True:
#      <a href='vscode-notebook-cell:/d%3A/2023-2024/RNN/Sokoban/Sokoban_MC_P.ipynb#X13sZmlsZQ%3D%3D?line=12'>13</a>     if time.time() - st_time < .2:
# ---> <a href='vscode-notebook-cell:/d%3A/2023-2024/RNN/Sokoban/Sokoban_MC_P.ipynb#X13sZmlsZQ%3D%3D?line=13'>14</a>         env.render()
#      <a href='vscode-notebook-cell:/d%3A/2023-2024/RNN/Sokoban/Sokoban_MC_P.ipynb#X13sZmlsZQ%3D%3D?line=14'>15</a>         rendered_frame += 1
#      <a href='vscode-notebook-cell:/d%3A/2023-2024/RNN/Sokoban/Sokoban_MC_P.ipynb#X13sZmlsZQ%3D%3D?line=15'>16</a>         time.sleep(1/144)
#
# File d:\2023-2024\RNN\Sokoban\SokobanEnv\lib\site-packages\gym\core.py:295, in Wrapper.render(self, mode, **kwargs)
#     294 def render(self, mode="human", **kwargs):
# --> 295     return self.env.render(mode, **kwargs)
#
# File d:\2023-2024\rnn\sokoban\gym-sokoban\gym_sokoban\envs\sokoban_env.py:315, in SokobanEnv.render(self, mode, close, scale)
#     312 def render(self, mode='human', close=None, scale=1):
#     313     assert mode in RENDERING_MODES
# --> 315     img = self.get_image(mode, scale)
#     317     if 'rgb_array' in mode:
#     318         return img
#
# File d:\2023-2024\rnn\sokoban\gym-sokoban\gym_sokoban\envs\sokoban_env.py:335, in SokobanEnv.get_image(self, mode, scale)
#     333     img = room_to_tiny_world_rgb(self.room_state, self.room_fixed, scale=scale)
#     334 else:
# --> 335     img = room_to_rgb(self.room_state,self.current_frame, self.room_fixed,self.pending_init_render,item=self.items,facing_right=self.last_action != 3)
#     336     self.pending_init_render = False
#     337     self.current_frame += 1
#
# File d:\2023-2024\rnn\sokoban\gym-sokoban\gym_sokoban\envs\render_utils.py:226, in room_to_rgb(room, frame, room_structure, init, item, facing_right)
#     222 #crop
#     223 room = room[min_row:max_row+1,min_col:max_col+1]
# --> 226 aris.seek(frame % aris.n_frames)
#     227 arisu = aris.copy()
#     228 if not facing_right:
#
# File d:\2023-2024\RNN\Sokoban\SokobanEnv\lib\site-packages\PIL\GifImagePlugin.py:151, in GifImageFile.seek(self, frame)
#     149 for f in range(self.__frame + 1, frame + 1):
#     150     try:
# --> 151         self._seek(f)
#     152     except EOFError as e:
#     153         self.seek(last_frame)
#
# File d:\2023-2024\RNN\Sokoban\SokobanEnv\lib\site-packages\PIL\GifImagePlugin.py:180, in GifImageFile._seek(self, frame, update_image)
#     177 if self.__offset:
#     178     # backup to last frame
#     179     self.fp.seek(self.__offset)
# --> 180     while self.data():
#     181         pass
#     182     self.__offset = 0
#
# File d:\2023-2024\RNN\Sokoban\SokobanEnv\lib\site-packages\PIL\GifImagePlugin.py:71, in GifImageFile.data(self)
#      70 def data(self):
# ---> 71     s = self.fp.read(1)
#      72     if s and s[0]:
#      73         return self.fp.read(s[0])
#
# KeyboardInterrupt:

# %%
ACTION_LOOKUP
# Out:
# {0: 'right', 1: 'up', 2: 'down', 3: 'left', 4: 'extinguish'}

# %%
_ = env.reset()
state = env.unwrapped.serialize_state()

# %%
action = 1
next_state, reward, done, info = env.step(action)
env.render()
print("Action: {} Reward: {}".format(ACTION_LOOKUP[action],reward))
# Out:
# Action: up Reward: 7.8469999999999995

# %%
for v in V.values():
    print(np.round(v,2))
# Out:
# [13.06 13.11 13.14 15.45 13.19]
# [13.13 13.78 13.78 16.39 13.75]
# [13.92 14.94 14.92 17.77 15.  ]
# [15.66 16.48 20.2  15.84  8.77]
# [16.43 15.2  15.18 14.73  8.71]
# [16.66 14.86 15.69 14.84  8.73]
# [15.43 15.99 16.03 15.27 17.58]
# [15.11 15.04 15.05 15.97 15.7 ]
# [18.97 20.92 18.92 18.35  9.78]
# [21.81 19.99 19.1  19.03  9.79]
# [17.18 19.2  17.06 17.37  9.72]
# [20.15 18.32 17.26 18.26  9.73]
# [22.62 21.   20.95 19.99  9.78]
# [22.21 21.9  21.85 21.15 23.5 ]
# [23.86 22.78 23.79 22.15 14.76]
# [23.24 23.21 23.25 22.77 24.43]
# [16.62 16.99 18.1  16.68 16.99]
# [16.15 16.28 16.12 16.94 16.12]
# [17.76 17.09 18.93 17.71 17.75]
# [17.02 16.19 16.21 16.42 16.18]
# [17.08 14.02 14.88 14.51  8.71]
# [18.59 19.38 18.57 18.59 14.55]
# [21.31 21.23 21.2  21.13 23.14]
# [19.09 18.65 18.65 19.1  20.15]
# [19.22 18.45 18.93 17.65 14.5 ]
# [22.49 20.82 21.08 19.9  14.65]
# [19.81 18.24 17.   17.31 14.52]
